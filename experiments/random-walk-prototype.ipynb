# %%
import os
os.chdir('..')
import numpy as np
from src.graph.Graph import UndirectedGraph
from src.algorithms.random_walk import RandomWalker
from src.algorithms.redundant_visitations import IRT


np.random.seed(1)

# %%
g = UndirectedGraph()
walker_texas_ranger = RandomWalker(g)
for i in range(100):
    g.add_node(str(i))
for i in range(10):
    for j in range(10):
        if i != j:
            g.add_edge(str(i), str(j), np.random.rand(1))
path = walker_texas_ranger.run(10)
rv = IRT.calculate(path)
print(path)
print(rv)
# Out:
# ['5', '6', '3', '5', '8', '3', '9', '5', '0', '9']
# [(None, '5', 0), ('5', '6', 0), ('6', '3', 0), ('3', '8', 1), ('8', '9', 1), ('9', '0', 1)]

# %%
# import numpy as np
# import os
# os.chdir('..')
from src.graph.semantic_network import SemanticNetwork
from src.text.text_wrangler import Corpus
from gensim.models import Word2Vec
# Out:
# C:\Users\jacob\Anaconda3\lib\site-packages\gensim\utils.py:1197: UserWarning: detected Windows; aliasing chunkize to chunkize_serial
#   warnings.warn("detected Windows; aliasing chunkize to chunkize_serial")

# %%
shakespeare = Corpus("docs/shakespeare.txt")
model = Word2Vec(shakespeare.sentence_matrix, size = 120,
                 window = 5, min_count=5, workers=8, sg=1)

# %%
network = SemanticNetwork(embeddings=model.wv.vectors, aligned_keys=model.wv.index2word)

# %%
for i in range(1000):
    model.train(shakespeare.sentence_matrix, total_examples=len(shakespeare.sentence_matrix),
                epochs=1, compute_loss=True)
    print("Round {} ==================".format(i))
    network.update(em_proportion=1, g_proportion=1, include_set=shakespeare.nouns, stop_set=shakespeare.stopwords, thresh=0.8, verbose=True)
# Out:
# Round 0 ==================
# Updated 4187668 edges
# Round 1 ==================
# Updated 2375388 edges
# Round 2 ==================
# Updated 1161502 edges
# Round 3 ==================
# Updated 505136 edges
# Round 4 ==================
# Updated 214866 edges
# Round 5 ==================
# Updated 97938 edges
# Round 6 ==================
# Updated 51382 edges
# Round 7 ==================
# Updated 31360 edges
# Round 8 ==================
# Updated 21554 edges
# Round 9 ==================
# Updated 16324 edges
# Round 10 ==================
# Updated 13492 edges
# Round 11 ==================
# Updated 11530 edges
# Round 12 ==================
# Updated 10252 edges
# Round 13 ==================
# Updated 9370 edges
# Round 14 ==================
# Updated 8686 edges
# Round 15 ==================
# Updated 8224 edges
# Round 16 ==================
# Updated 7812 edges
# Round 17 ==================
# Updated 7444 edges
# Round 18 ==================
# Updated 7106 edges
# Round 19 ==================
# Updated 6830 edges
# Round 20 ==================
# Updated 6578 edges
# Round 21 ==================
# Updated 6396 edges
# Round 22 ==================
# Updated 6178 edges
# Round 23 ==================
# Updated 6024 edges
# Round 24 ==================
# Updated 5862 edges
# Round 25 ==================
# Updated 5702 edges
# Round 26 ==================
# Updated 5576 edges
# Round 27 ==================
# Updated 5484 edges
# Round 28 ==================
# Updated 5374 edges
# Round 29 ==================
# Updated 5278 edges
# Round 30 ==================
# Updated 5196 edges
# Round 31 ==================
# Updated 5122 edges
# Round 32 ==================
# Updated 5058 edges
# Round 33 ==================
# Updated 4998 edges
# Round 34 ==================
# Updated 4952 edges
# Round 35 ==================
# Updated 4896 edges
# Round 36 ==================
# Updated 4858 edges
# Round 37 ==================
# Updated 4832 edges
# Round 38 ==================
# Updated 4786 edges
# Round 39 ==================
# Updated 4754 edges
# Round 40 ==================
# Updated 4732 edges
# Round 41 ==================
# Updated 4700 edges
# Round 42 ==================
# Updated 4672 edges
# Round 43 ==================
# Updated 4654 edges
# Round 44 ==================
# Updated 4628 edges
# Round 45 ==================
# Updated 4606 edges
# Round 46 ==================
# Updated 4590 edges
# Round 47 ==================
# Updated 4572 edges
# Round 48 ==================
# Updated 4562 edges
# Round 49 ==================
# Updated 4550 edges
# Round 50 ==================
# Updated 4526 edges
# Round 51 ==================
# Updated 4516 edges
# Round 52 ==================
# Updated 4502 edges
# Round 53 ==================
# Updated 4498 edges
# Round 54 ==================
# Updated 4494 edges
# Round 55 ==================
# Updated 4482 edges
# Round 56 ==================
# Updated 4480 edges
# Round 57 ==================
# Updated 4476 edges
# Round 58 ==================
# Updated 4468 edges
# Round 59 ==================
# Updated 4460 edges
# Round 60 ==================
# Updated 4448 edges
# Round 61 ==================
# Updated 4440 edges
# Round 62 ==================
# Updated 4436 edges
# Round 63 ==================
# Updated 4434 edges
# Round 64 ==================
# Updated 4434 edges
# Round 65 ==================
# Updated 4428 edges
# Round 66 ==================
# Updated 4428 edges
# Round 67 ==================
# Updated 4424 edges
# Round 68 ==================
# Updated 4422 edges
# Round 69 ==================
# Updated 4416 edges
# Round 70 ==================
# Updated 4414 edges
# Round 71 ==================
# Updated 4412 edges
# Round 72 ==================
# Updated 4408 edges
# Round 73 ==================
# Updated 4406 edges
# Round 74 ==================
# Updated 4404 edges
# Round 75 ==================
# Updated 4394 edges
# Round 76 ==================
# Updated 4384 edges
# Round 77 ==================
# Updated 4374 edges
# Round 78 ==================
# Updated 4372 edges
# Round 79 ==================
# Updated 4370 edges
# Round 80 ==================
# Updated 4370 edges
# Round 81 ==================
# Updated 4368 edges
# Round 82 ==================
# Updated 4366 edges
# Round 83 ==================
# Updated 4362 edges
# Round 84 ==================
# Updated 4358 edges
# Round 85 ==================
# Updated 4354 edges
# Round 86 ==================
# Updated 4354 edges
# Round 87 ==================
# Updated 4352 edges
# Round 88 ==================
# Updated 4352 edges
# Round 89 ==================
# Updated 4350 edges
# Round 90 ==================
# Updated 4344 edges
# Round 91 ==================
# Updated 4342 edges
# Round 92 ==================
# Updated 4344 edges
# Round 93 ==================
# Updated 4340 edges
# Round 94 ==================
# Updated 4336 edges
# Round 95 ==================
# Updated 4336 edges
# Round 96 ==================
# Updated 4338 edges
# Round 97 ==================
# Updated 4336 edges
# Round 98 ==================
# Updated 4336 edges
# Round 99 ==================
# Updated 4336 edges
# Round 100 ==================
# Updated 4336 edges
# Round 101 ==================
# Updated 4332 edges
# Round 102 ==================
# Updated 4332 edges
# Round 103 ==================
# Updated 4330 edges
# Round 104 ==================
# Updated 4330 edges
# Round 105 ==================
# Updated 4330 edges
# Round 106 ==================
# Updated 4330 edges
# Round 107 ==================
# Updated 4330 edges
# Round 108 ==================
# Updated 4328 edges
# Round 109 ==================
# Updated 4332 edges
# Round 110 ==================
# Updated 4326 edges
# Round 111 ==================
# Updated 4326 edges
# Round 112 ==================
# Updated 4324 edges
# Round 113 ==================
# Updated 4320 edges
# Round 114 ==================
# Updated 4324 edges
# Round 115 ==================
# Updated 4318 edges
# Round 116 ==================
# Updated 4318 edges
# Round 117 ==================
# Updated 4318 edges
# Round 118 ==================
# Updated 4320 edges
# Round 119 ==================
# Updated 4316 edges
# Round 120 ==================
# Updated 4316 edges
# Round 121 ==================
# Updated 4314 edges
# Round 122 ==================
# Updated 4314 edges
# Round 123 ==================
# Updated 4314 edges
# Round 124 ==================
# Updated 4312 edges
# Round 125 ==================
# Updated 4312 edges
# Round 126 ==================
# Updated 4308 edges
# Round 127 ==================
# Updated 4308 edges
# Round 128 ==================
# Updated 4306 edges
# Round 129 ==================
# Updated 4304 edges
# Round 130 ==================
# Updated 4302 edges
# Round 131 ==================
# Updated 4298 edges
# Round 132 ==================
# Updated 4298 edges
# Round 133 ==================
# Updated 4296 edges
# Round 134 ==================
# Updated 4296 edges
# Round 135 ==================
# Updated 4292 edges
# Round 136 ==================
# Updated 4290 edges
# Round 137 ==================
# Updated 4294 edges
# Round 138 ==================
# Updated 4292 edges
# Round 139 ==================
# Updated 4290 edges
# Round 140 ==================
# Updated 4290 edges
# Round 141 ==================
# Updated 4286 edges
# Round 142 ==================
# Updated 4288 edges
# Round 143 ==================
# Updated 4288 edges
# Round 144 ==================
# Updated 4286 edges
# Round 145 ==================
# Updated 4286 edges
# Round 146 ==================
# Updated 4286 edges
# Round 147 ==================
# Updated 4284 edges
# Round 148 ==================
# Updated 4286 edges
# Round 149 ==================
# Updated 4284 edges
# Round 150 ==================
# Updated 4282 edges
# Round 151 ==================
# Updated 4276 edges
# Round 152 ==================
# Updated 4274 edges
# Round 153 ==================
# Updated 4278 edges
# Round 154 ==================
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-f86bedc03617> in <module>
#       3                 epochs=1, compute_loss=True)
#       4     print("Round {} ==================".format(i))
# ----> 5     network.update(em_proportion=1, g_proportion=1, include_set=shakespeare.nouns, stop_set=shakespeare.stopwords, thresh=0.8, verbose=True)
#
# ~\Documents\PSU\2019\Winter\CS-441-AI\FinalProject\src\graph\semantic_network.py in update(self, em_proportion, g_proportion, include_set, stop_set, thresh, verbose)
#      30         )
#      31
# ---> 32         self._update(em_subset, g_subset, thresh, verbose)
#      33
#      34     def _update(self, em_subset, g_subset, thresh, verbose=False):
#
# ~\Documents\PSU\2019\Winter\CS-441-AI\FinalProject\src\graph\semantic_network.py in _update(self, em_subset, g_subset, thresh, verbose)
#      44         updated = 0
#      45         for i, em_i in enumerate(em_subset):
# ---> 46             for j, g_j in enumerate(g_subset):
#      47                 if cos_sims[i, j] >= thresh:
#      48                     self.graph.add_edge(self.index_to_key[em_i], self.index_to_key[g_j], cos_sims[i, j])
#
# KeyboardInterrupt:

# %%
wtr = RandomWalker(network.graph)

# %%
path = wtr.run(1000)
path
# Out:
# ['infirmity',
#  'provision',
#  'loathes',
#  'infer',
#  'foil',
#  'profession',
#  'accusation',
#  'hallow',
#  'penalty',
#  'quillets',
#  'capacity',
#  'taunt',
#  'commonweal',
#  'reynaldo',
#  'carlisle',
#  'amiens',
#  'fortinbras',
#  'bushy',
#  'surveyor',
#  'cinna',
#  'messala',
#  'portia',
#  'iachimo',
#  'francisco',
#  'cimber',
#  'francisco',
#  'paulina',
#  'aeneas',
#  'miranda',
#  'morocco',
#  'banquo',
#  'menteith',
#  'discovers',
#  'sleeper',
#  'sennet',
#  'albans',
#  'snug',
#  'calchas',
#  'brothel',
#  'batter',
#  'quiver',
#  'misfortune',
#  'griev',
#  'suppos',
#  'canon',
#  'fort',
#  'tenour',
#  'whiteness',
#  'cricket',
#  'proclamation',
#  'refrain',
#  'alcides',
#  'resistance',
#  'welshman',
#  'pilgrim',
#  'bandy',
#  'precept',
#  'recorder',
#  'ivy',
#  'doctrine',
#  'expo',
#  'lump',
#  'humane',
#  'indignity',
#  'mischance',
#  'accord',
#  'blanket',
#  'restless',
#  'obeys',
#  'inhabit',
#  'deface',
#  'scoff',
#  'tyrus',
#  'travell',
#  'sandy',
#  'drowns',
#  'likelihood',
#  'trap',
#  'barefoot',
#  'licence',
#  'burthen',
#  'deceit',
#  'arrival',
#  'vicar',
#  'thunderbolt',
#  'chough',
#  'cake',
#  'range',
#  'household',
#  'arrogance',
#  'ides',
#  'armes',
#  'ilium',
#  'fulness',
#  'reckon',
#  'travell',
#  'sandy',
#  'sixpence',
#  'polydore',
#  'abides',
#  'magistrate',
#  'shipping',
#  'courtship',
#  'humility',
#  'downfall',
#  'persuades',
#  'impostor',
#  'impiety',
#  'moone',
#  'comforter',
#  'gibe',
#  'distraction',
#  'platform',
#  'boldness',
#  'deity',
#  'chap',
#  'discomfort',
#  'despatch',
#  'orsino',
#  'jeweller',
#  'lawrence',
#  'jaques',
#  'miranda',
#  'loo',
#  'bonnet',
#  'ache',
#  'potion',
#  'bran',
#  'sunshine',
#  'practis',
#  'suppos',
#  'incorporate',
#  'gratis',
#  'nativity',
#  'crutch',
#  'fume',
#  'co',
#  'peascod',
#  'garb',
#  'fresher',
#  'chaff',
#  'barber',
#  'swim',
#  'decline',
#  'awakes',
#  'engag',
#  'defac',
#  'caparison',
#  'bearer',
#  'newes',
#  'consume',
#  'pulse',
#  'restore',
#  'eies',
#  'refuge',
#  'curer',
#  'conjurer',
#  'examination',
#  'wond',
#  'nursing',
#  'rescu',
#  'sallet',
#  'prophesy',
#  'strangle',
#  'joiner',
#  'admittance',
#  'payment',
#  'graze',
#  'buzzing',
#  'snare',
#  'inconstancy',
#  'cramp',
#  'smack',
#  'reliev',
#  'harp',
#  'slack',
#  'pestilent',
#  'giv',
#  'fortitude',
#  'mare',
#  'neat',
#  'flung',
#  'hereof',
#  'appointment',
#  'salutation',
#  'dunghill',
#  'depriv',
#  'chivalry',
#  'sicilius',
#  'greed',
#  'depends',
#  'embracement',
#  'shuts',
#  'woodcock',
#  'limitation',
#  'parthia',
#  'occupation',
#  'tumult',
#  'examination',
#  'angle',
#  'troyan',
#  'mistris',
#  'ace',
#  'levity',
#  'portion',
#  'pill',
#  'antium',
#  'herod',
#  'incorporate',
#  'impatience',
#  'attorney',
#  'poetry',
#  'penalty',
#  'consort',
#  'jig',
#  'importance',
#  'road',
#  'artillery',
#  'ditty',
#  'family',
#  'monarchy',
#  'adverse',
#  'cramp',
#  'receives',
#  'ruler',
#  'thunderbolt',
#  'fer',
#  'durance',
#  'prophetess',
#  'orient',
#  'fin',
#  'thorny',
#  'deign',
#  'epithet',
#  'misuse',
#  'clearer',
#  'disobedience',
#  'cramp',
#  'busines',
#  'soonest',
#  'speechless',
#  'forfeiture',
#  'rust',
#  'adonis',
#  'transparent',
#  'recoil',
#  'planet',
#  'asunder',
#  'lethe',
#  'canker',
#  'batter',
#  'predecessor',
#  'synod',
#  'salutation',
#  'musicke',
#  'montagues',
#  'cote',
#  'founder',
#  'misfortune',
#  'sall',
#  'cricket',
#  'te',
#  'pedant',
#  'donalbain',
#  'voltemand',
#  'cinna',
#  'chatillon',
#  'hood',
#  'soever',
#  'scotch',
#  'packet',
#  'keel',
#  'ruthless',
#  'oppos',
#  'hardness',
#  'homage',
#  'transform',
#  'giv',
#  'dump',
#  'ivory',
#  'maim',
#  'puissance',
#  'quillets',
#  'thereto',
#  'distill',
#  'nerve',
#  'rend',
#  'assistance',
#  'lot',
#  'clutch',
#  'confines',
#  'enforcement',
#  'surfeit',
#  'imputation',
#  'bleat',
#  'fulness',
#  'grudge',
#  'enlargement',
#  'lobby',
#  'pitch',
#  'mane',
#  'dirt',
#  'motif',
#  'venison',
#  'louder',
#  'retort',
#  'swagger',
#  'declin',
#  'antiquity',
#  'saith',
#  'pupil',
#  'trail',
#  'porpentine',
#  'wanteth',
#  'mix',
#  'scotch',
#  'griev',
#  'pluto',
#  'dissolve',
#  'nerve',
#  'porch',
#  'forres',
#  'un',
#  'prospect',
#  'construction',
#  'scandal',
#  'recoil',
#  'damnation',
#  'brush',
#  'fruitless',
#  'discomfort',
#  'clutch',
#  'ascends',
#  'doctrine',
#  'bulk',
#  'sale',
#  'ptolemy',
#  'dispraise',
#  'beseeming',
#  'drab',
#  'woos',
#  'restor',
#  'attorney',
#  'accus',
#  'receiv',
#  'measur',
#  'supple',
#  'compliance',
#  'gesture',
#  'material',
#  'suburb',
#  'illusion',
#  'huswife',
#  'worke',
#  'breathless',
#  'drab',
#  'pill',
#  'shackle',
#  'talent',
#  'flock',
#  'poise',
#  'beck',
#  'caparison',
#  'conspire',
#  'minist',
#  'tail',
#  'tress',
#  'apple',
#  'fray',
#  'silius',
#  'salvation',
#  'proclamation',
#  'charter',
#  'homage',
#  'defendant',
#  'glutton',
#  'escap',
#  'eate',
#  'ooze',
#  'foretell',
#  'bravery',
#  'banner',
#  'stormy',
#  'orange',
#  'cake',
#  'eate',
#  'rung',
#  'bin',
#  'chanc',
#  'insult',
#  'grudge',
#  'rout',
#  'reveal',
#  'comforter',
#  'damage',
#  'montagues',
#  'inland',
#  'whiter',
#  'augustus',
#  'cattle',
#  'prune',
#  'smelling',
#  'seed',
#  'humanity',
#  'beside',
#  'potion',
#  'strangeness',
#  'disobedient',
#  'mirror',
#  'card',
#  'taunt',
#  'devi',
#  'chaff',
#  'antique',
#  'dissolv',
#  'balance',
#  'penitence',
#  'compound',
#  'hotter',
#  'speechless',
#  'lubber',
#  'ass',
#  'edition',
#  'ginger',
#  'bode',
#  'welfare',
#  'sardis',
#  'quietness',
#  'diet',
#  'persuades',
#  'griev',
#  'captivity',
#  'disputation',
#  'fortitude',
#  'discreet',
#  'pinion',
#  'wrangling',
#  'trap',
#  'interlude',
#  'engenders',
#  'vulture',
#  'droop',
#  'purge',
#  'gamut',
#  'messina',
#  'prophecy',
#  'tongu',
#  'fun',
#  'rode',
#  'vpon',
#  'worthless',
#  'rudeness',
#  'dealt',
#  'porpentine',
#  'encompass',
#  'stature',
#  'aqua',
#  'wren',
#  'flinty',
#  'maw',
#  'phoebus',
#  'confines',
#  'bribe',
#  'bitterness',
#  'chivalry',
#  'deputation',
#  'support',
#  'newes',
#  'dispute',
#  'consist',
#  'reproach',
#  'engage',
#  'butchery',
#  'tenth',
#  'mutton',
#  'celerity',
#  'quondam',
#  'beseeming',
#  'receives',
#  'continuance',
#  'wormwood',
#  'declin',
#  'mingle',
#  'fortitude',
#  'vail',
#  'saide',
#  'unsure',
#  'cambio',
#  'disclaim',
#  'declin',
#  'reconcile',
#  'defy',
#  'lecture',
#  'tool',
#  'beef',
#  'eloquence',
#  'compassion',
#  'drone',
#  'battlement',
#  'ravenspurgh',
#  'insurrection',
#  'lackey',
#  'wedlock',
#  'flag',
#  'donate',
#  'coach',
#  'forbids',
#  'abstinence',
#  'clay',
#  'leapt',
#  'conception',
#  'politician',
#  'cine',
#  'manifold',
#  'ruminate',
#  'examination',
#  'drain',
#  'thatch',
#  'ate',
#  'saide',
#  'resist',
#  'vulture',
#  'hay',
#  'unity',
#  'mutton',
#  'poland',
#  'mutton',
#  'chink',
#  'shuns',
#  'mourner',
#  'vizard',
#  'baboon',
#  'impatience',
#  'tereus',
#  'gregory',
#  'ascension',
#  'godlike',
#  'stalk',
#  'tongu',
#  'verdict',
#  'botch',
#  'dusky',
#  'gaudy',
#  'pie',
#  'incertain',
#  'gyves',
#  'heresy',
#  'maze',
#  'tereus',
#  'delivers',
#  'sleepe',
#  'mustard',
#  'slide',
#  'retain',
#  'swagger',
#  'abstract',
#  'hovel',
#  'period',
#  'founder',
#  'practis',
#  'orient',
#  'pestilence',
#  'controversy',
#  'mickle',
#  'selfe',
#  'rapt',
#  'glance',
#  'duly',
#  'bate',
#  'houre',
#  'drudge',
#  'puff',
#  'quell',
#  'environ',
#  'imitation',
#  'palmer',
#  'frustrate',
#  'fals',
#  'quod',
#  'tiber',
#  'hurry',
#  'devours',
#  'fortress',
#  'venge',
#  'beseeming',
#  'weal',
#  'hearer',
#  'manage',
#  'unclasp',
#  'prophetess',
#  'supple',
#  'commune',
#  'arrogance',
#  'annoyance',
#  'plenty',
#  'gaudy',
#  'family',
#  'examination',
#  'waxen',
#  'quiver',
#  'cripple',
#  'halt',
#  'mystery',
#  'mislike',
#  'whoe',
#  'expostulate',
#  'bonny',
#  'mildness',
#  'faile',
#  'refrain',
#  'acre',
#  'radiant',
#  'decree',
#  'digg',
#  'hymn',
#  'beare',
#  'oration',
#  'cattle',
#  'haggard',
#  'reconcile',
#  'operation',
#  'twig',
#  'amazement',
#  'shackle',
#  'cue',
#  'potency',
#  'subdues',
#  'reflection',
#  'bruise',
#  'brooch',
#  'delicate',
#  'cleft',
#  'bliss',
#  'misuse',
#  'ar',
#  'shap',
#  'lodowick',
#  'mightiness',
#  'wretchedness',
#  'dunghill',
#  'citadel',
#  'musty',
#  'bolder',
#  'polack',
#  'enlarge',
#  'dealt',
#  'preservation',
#  'cram',
#  'admittance',
#  'chaff',
#  'grudge',
#  'speaker',
#  'synod',
#  'ravenspurgh',
#  'sequent',
#  'gallop',
#  'basilisk',
#  'scatt',
#  'abram',
#  'tewksbury',
#  'brew',
#  'lodowick',
#  'wardrobe',
#  'gallia',
#  'forbids',
#  'member',
#  'society',
#  'heare',
#  'ken',
#  'wardrobe',
#  'loathes',
#  'sweat',
#  'blanket',
#  'retirement',
#  'ruthless',
#  'control',
#  'mockery',
#  'labor',
#  'avail',
#  'dismiss',
#  'reveal',
#  'reproof',
#  'transformation',
#  'corinth',
#  'clutch',
#  'sweetheart',
#  'card',
#  'precept',
#  'dram',
#  'trophy',
#  'thames',
#  'massy',
#  'repay',
#  'attempt',
#  'concern',
#  'belongs',
#  'favor',
#  'inventory',
#  'penance',
#  'bitterness',
#  'strut',
#  'caparison',
#  'shrine',
#  'ague',
#  'clad',
#  'claw',
#  'lamenting',
#  'chaplain',
#  'bereave',
#  'idolatry',
#  'mistrust',
#  'foolery',
#  'pinion',
#  'chastise',
#  'gnaw',
#  'ravenspurgh',
#  'berry',
#  'pastime',
#  'disgrace',
#  'frame',
#  'hitherto',
#  'remainder',
#  'restrain',
#  'reservation',
#  'foster',
#  'obligation',
#  'unclasp',
#  'contention',
#  'grease',
#  'meditation',
#  'relent',
#  'style',
#  'chastise',
#  'damage',
#  'troyan',
#  'obstinate',
#  'strangeness',
#  'blaze',
#  'undergo',
#  'cable',
#  'cherubins',
#  'fainting',
#  'advancement',
#  'boon',
#  'atone',
#  'circumstance',
#  'judgement',
#  'difficulty',
#  'tinker',
#  'foole',
#  'lechery',
#  'handsome',
#  'parthia',
#  'province',
#  'discovery',
#  'broach',
#  'excels',
#  'slippery',
#  'porpentine',
#  'quillets',
#  'divinity',
#  'text',
#  'antipode',
#  'hairy',
#  'fraud',
#  'blacker',
#  'chok',
#  'quietness',
#  'pigeon',
#  'latch',
#  'perfume',
#  'wherever',
#  'peck',
#  'consist',
#  'wasp',
#  'strip',
#  'fin',
#  'client',
#  'carcass',
#  'gut',
#  'rouen',
#  'puissant',
#  'lethargy',
#  'appointment',
#  'judg',
#  'peru',
#  'disperse',
#  'icy',
#  'pine',
#  'vigour',
#  'lawn',
#  'altar',
#  'defac',
#  'fortress',
#  'contention',
#  'hearse',
#  'union',
#  'volley',
#  'cadwal',
#  'dissolution',
#  'beck',
#  'immodest',
#  'fortress',
#  'tribe',
#  'armor',
#  'porpentine',
#  'impostor',
#  'annoyance',
#  'smelling',
#  'darest',
#  'hart',
#  'chill',
#  'kernel',
#  'enlargement',
#  'sequent',
#  'defil',
#  'dialogue',
#  'soe',
#  'strives',
#  'friday',
#  'adore',
#  'hobby',
#  'timandra',
#  'pridge',
#  'mercury',
#  'entrap',
#  'ertake',
#  'discus',
#  'tucket',
#  'twig',
#  'excels',
#  'prettiest',
#  'observance',
#  'cambio',
#  'shap',
#  'cine',
#  'horseback',
#  'hum',
#  'valerius',
#  'restrain',
#  'lighter',
#  'travell',
#  'bald',
#  'interr',
#  'fulfill',
#  'sinister',
#  'mess',
#  'mann',
#  'damage',
#  'luggage',
#  'skip',
#  'boyes',
#  'celerity',
#  'fowl',
#  'sanctity',
#  'helicane',
#  'obsequies',
#  'sleeper',
#  'government',
#  'bondman',
#  'hum',
#  'hog',
#  'whelp',
#  'pudding',
#  'village',
#  'mi',
#  'quittance',
#  'brake',
#  'gorge',
#  'islander',
#  'mi',
#  'scatt',
#  'liquor',
#  'bit',
#  'daw',
#  'mote',
#  'wrung',
#  'suburb',
#  'braver',
#  'armor',
#  'pat',
#  'warmth',
#  'shipp',
#  'beleeve',
#  'manifold',
#  'epithet',
#  'idiot',
#  'cesario',
#  'prosperity',
#  'bulwark',
#  'solemnity',
#  'ides',
#  'thames',
#  'valerius',
#  'lecture',
#  'hover',
#  'desolation',
#  'rout',
#  'vasty',
#  'co',
#  'trim',
#  'sulphur',
#  'festival',
#  'dealt',
#  'perdition',
#  'plainness',
#  'diligence',
#  'discreet',
#  'gesture',
#  'pith',
#  'gramercy',
#  'repute',
#  'hay',
#  'saturn',
#  'status',
#  'fount',
#  'mann',
#  'thrall',
#  'bonfire',
#  'control',
#  'delivers',
#  'celerity',
#  'propose',
#  'shuts',
#  'buckle',
#  'belie',
#  'forsake',
#  'persuasion',
#  'lass',
#  'button',
#  'perdition',
#  'cancel',
#  'shuns',
#  'rialto',
#  'ow',
#  'helicane',
#  'crust',
#  'utterance',
#  'knell',
#  'infringe',
#  'pattern',
#  'forbearance',
#  'iniquity',
#  'environ',
#  'dealt',
#  'smack',
#  'grease',
#  'exaction',
#  'team',
#  'mutius',
#  'highway',
#  'againe',
#  'fresher',
#  'bread',
#  'limitation',
#  'fortitude',
#  'soil',
#  'property',
#  'obeys',
#  'brainford',
#  'gardener',
#  'poland',
#  'chop',
#  'bodes',
#  'divinity',
#  'stagger',
#  'aqua',
#  'yee',
#  'loo',
#  'gin',
#  'howsoe',
#  'dimension',
#  'enlargement',
#  'parthia',
#  'interpreter',
#  'butter',
#  'posterity',
#  'keepe',
#  'vulture',
#  'ague',
#  'morris',
#  'quillets',
#  'counsellor',
#  'declare',
#  'employment',
#  'preach',
#  'huswife',
#  'cape',
#  'reform',
#  'observation',
#  'compulsion',
#  'mickle',
#  'bum',
#  'evasion',
#  'oui',
#  'procession',
#  'tereus',
#  'presage',
#  'adjunct',
#  'immodest']

# %%
tot = 0
for x in IRT.calculate(path): tot += x[2]
tot
# Out:
# 178

# %%
seen = set()
dup = set()
for x in path:
    if x in seen:
        dup.add(x)
    seen.add(x)
    
for x in dup:
    print(x)
# Out:
# grease
# eate
# twig
# mickle
# perdition
# trap
# contention
# grudge
# dunghill
# celerity
# aqua
# cinna
# practis
# impatience
# helicane
# admittance
# troyan
# beseeming
# homage
# hum
# quietness
# ides
# shap
# suburb
# travell
# damage
# pill
# parthia
# mann
# wardrobe
# cattle
# armor
# prophetess
# arrogance
# appointment
# divinity
# discreet
# proclamation
# family
# cine
# shuns
# bitterness
# recoil
# immodest
# fortitude
# precept
# sandy
# founder
# co
# persuades
# scatt
# scotch
# loathes
# ravenspurgh
# doctrine
# smelling
# thames
# delivers
# quiver
# confines
# valerius
# environ
# smack
# sequent
# reconcile
# tereus
# reveal
# francisco
# huswife
# annoyance
# lodowick
# montagues
# declin
# vulture
# chastise
# refrain
# shackle
# fresher
# ague
# chivalry
# beck
# quillets
# taunt
# newes
# incorporate
# rout
# enlargement
# potion
# griev
# suppos
# speechless
# nerve
# sleeper
# loo
# consist
# forbids
# supple
# mi
# control
# card
# unclasp
# poland
# caparison
# swagger
# saide
# pinion
# lecture
# gaudy
# excels
# thunderbolt
# tongu
# dealt
# restrain
# cramp
# comforter
# giv
# batter
# blanket
# cricket
# miranda
# penalty
# epithet
# limitation
# porpentine
# cambio
# gesture
# discomfort
# attorney
# fin
# mutton
# manifold
# orient
# misfortune
# strangeness
# salutation
# fortress
# obeys
# synod
# ruthless
# impostor
# chaff
# hay
# shuts
# receives
# clutch
# fulness
# drab
# examination
# cake
# defac
# misuse

# %%
'juliet' in shakespeare.nouns
# Out:
# False

# %%
'juliet' in shakespeare.adjectives
# Out:
# True

# %%
wtr = RandomWalker(network.graph, start='romeo')
path = wtr.run(100)
path
# Out:
# ['romeo',
#  'tybalt',
#  'imogen',
#  'cordelia',
#  'beadle',
#  'donalbain',
#  'servingman',
#  'dowager',
#  'wormwood',
#  'shone',
#  'appliance',
#  'pridge',
#  'tam',
#  'beguil',
#  'conduit',
#  'parasite',
#  'spout',
#  'surety',
#  'lubber',
#  'mightier',
#  'holder',
#  'accuser',
#  'allegiance',
#  'mistaken',
#  'chill',
#  'mislike',
#  'ewe',
#  'allowance',
#  'aqua',
#  'stillness',
#  'pupil',
#  'nerve',
#  'bribe',
#  'emulation',
#  'devours',
#  'bath',
#  'diet',
#  'provision',
#  'zounds',
#  'recreation',
#  'grudge',
#  'proclamation',
#  'unity',
#  'ace',
#  'misty',
#  'piercing',
#  'blanket',
#  'albion',
#  'tyre',
#  'morton',
#  'jourdain',
#  'cato',
#  'aeneas',
#  'antigonus',
#  'cleomenes',
#  'mace',
#  'clout',
#  'stirrup',
#  'libertine',
#  'roof',
#  'complement',
#  'craft',
#  'price',
#  'exception',
#  'dispos',
#  'advanc',
#  'mix',
#  'preserv',
#  'heav',
#  'diet',
#  'clasp',
#  'pageant',
#  'weather',
#  'competitor',
#  'subjection',
#  'material',
#  'sufferance',
#  'imprisonment',
#  'humanity',
#  'rack',
#  'presumption',
#  'par',
#  'hoard',
#  'lath',
#  'lawless',
#  'reproach',
#  'inheritance',
#  'bodes',
#  'favor',
#  'foeman',
#  'loathe',
#  'medicine',
#  'importance',
#  'bellario',
#  'radiant',
#  'orange',
#  'juice',
#  'alacrity',
#  'hay',
#  'liquor']
